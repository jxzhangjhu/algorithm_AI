# %%
nums = [0,1,2,2,3,0,4,2]
nums
# Out:
# [0, 1, 2, 2, 3, 0, 4, 2]

# %%
for i in range(1,len(nums)):
    nums[i-1] = nums[i]
    print('loop',i)
    i = i -1
    print('i value',i)
# Out:
# loop 1
# i value 0
# loop 2
# i value 1
# loop 3
# i value 2
# loop 4
# i value 3
# loop 5
# i value 4
# loop 6
# i value 5
# loop 7
# i value 6

# %%
nums
# Out:
# [1, 2, 2, 3, 0, 4, 2, 2]

# %%
nums = [0,1,2,2,3,0,4,2]
val = 2

i = 0
length = len(nums)
while i < len(nums):
    print(i)
    print(nums)
    if nums[i] == val:
        for j in range(i+1, len(nums)):
            nums[j-1] = nums[j]

        length -= 1
        i -= 1

    i += 1
# Out:
# 0
# [0, 1, 2, 2, 3, 0, 4, 2]
# 1
# [0, 1, 2, 2, 3, 0, 4, 2]
# 2
# [0, 1, 2, 2, 3, 0, 4, 2]
# 2
# [0, 1, 2, 3, 0, 4, 2, 2]
# 2
# [0, 1, 3, 0, 4, 2, 2, 2]
# 3
# [0, 1, 3, 0, 4, 2, 2, 2]
# 4
# [0, 1, 3, 0, 4, 2, 2, 2]
# 5
# [0, 1, 3, 0, 4, 2, 2, 2]
# 5
# [0, 1, 3, 0, 4, 2, 2, 2]
# 5
# [0, 1, 3, 0, 4, 2, 2, 2]
# 5
# [0, 1, 3, 0, 4, 2, 2, 2]
# 5
# [0, 1, 3, 0, 4, 2, 2, 2]
# 5
# [0, 1, 3, 0, 4, 2, 2, 2]
# 5
# [0, 1, 3, 0, 4, 2, 2, 2]
# 5
# [0, 1, 3, 0, 4, 2, 2, 2]
# 5
# [0, 1, 3, 0, 4, 2, 2, 2]
# 5
# [0, 1, 3, 0, 4, 2, 2, 2]
# 5
# [0, 1, 3, 0, 4, 2, 2, 2]
# 5
# [0, 1, 3, 0, 4, 2, 2, 2]
# 5
# [0, 1, 3, 0, 4, 2, 2, 2]
# 5
# [0, 1, 3, 0, 4, 2, 2, 2]
# 5
# [0, 1, 3, 0, 4, 2, 2, 2]
# 5
# [0, 1, 3, 0, 4, 2, 2, 2]
# 5
# [0, 1, 3, 0, 4, 2, 2, 2]
# 5
# [0, 1, 3, 0, 4, 2, 2, 2]
# 5
# [0, 1, 3, 0, 4, 2, 2, 2]
# 5
# [0, 1, 3, 0, 4, 2, 2, 2]
# 5
# [0, 1, 3, 0, 4, 2, 2, 2]
# 5
# [0, 1, 3, 0, 4, 2, 2, 2]
# 5
# [0, 1, 3, 0, 4, 2, 2, 2]
# 5
# [0, 1, 3, 0, 4, 2, 2, 2]
# 5
# [0, 1, 3, 0, 4, 2, 2, 2]
# 5
# ...

# %%
length
# Out:
# 5

# %%
nums
# Out:
# [0, 1, 2, 3, 0, 4, 2, 2]

# %%
s = ""

# %%
s = 'a b c'

# %%
s
# Out:
# 'a b c'

# %%
s[0]
# Out:
# 'a'

# %%
s[1]
# Out:
# ' '

# %%
s = ''
